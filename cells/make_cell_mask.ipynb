# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('datasets/train/image/image-final_0029.jpg', 0)  # gray
# blur = cv2.GaussianBlur(img, (45, 45), 0)
ret,thresh = cv2.threshold(img, 20, 255, cv2.THRESH_BINARY)  # 17
# edges = cv2.Canny(img, 10, 20)
# laplacian = cv2.Laplacian(thresh, cv2.CV_64F)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.title('origin')
plt.subplot(122)
plt.imshow(thresh, cmap='gray')
plt.title('threshold')
plt.show()

# %%
kernel = np.ones((3, 3), np.uint8)
erosion = cv2.erode(thresh, kernel, iterations=3)
# kernel = np.ones((3, 3), np.uint8)
# dilation = cv2.dilate(thresh, kernel, iterations=1)
# closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
plt.imshow(erosion, cmap='gray')

# %%
cv2.imwrite('datasets/train/mask/mask-final_0029.jpg', erosion)
# Out:
# True
